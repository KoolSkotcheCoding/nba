# %%
import numpy as np
from scipy import integrate
import sys
sys.path.append('/home/keith/nba/build')
import nbaGame, nbaPlot#, nbaAnimation
from nbaAnimation import plot_event
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation
# %matplotlib inline
import json
with open('/nbaData/0021500491.json') as data_file:
    bata=json.load(data_file)


testGame=nbaGame.NBA_game(bata)

recievedPoss,posTempPoss=testGame.getEventData(3,ball=True,time=True,players=testGame.players)
eventPlayers=[player for player in  list(posTempPoss.columns.levels[0]) if player !='time' and player !='near ball']

# %%
posTempPoss.query




#posTempPoss['time'].query('gameClock<706.00 and gameClock>705.00').shape

# %%
plot_event(posTempPoss,players=eventPlayers,trajectory=False,threeD=True,saveFile='twoD.mp4')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
